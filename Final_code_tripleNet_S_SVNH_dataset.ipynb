# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun May 19 15:31:31 2024
"""
import h5py
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import matplotlib.pyplot as plt

h5f = h5py.File('/content/drive/MyDrive/SVHN_single_grey1.h5', 'r')

x_train = h5f['X_train'][:]
y_train = h5f['y_train'][:]
x_test = h5f['X_test'][:]
y_test = h5f['y_test'][:]

h5f.close() #close this file

# Preprocessing
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# One-hot encode labels (if needed for your model)
# This converts a vector of integer class labels to a binary matrix.

# Print the shapes of the preprocessed data
print("Train images shape:", x_train.shape)
print("Test images shape:", x_test.shape)
print("Train labels shape:", y_train.shape)
print("Test labels shape:", y_test.shape)

# Creating TripleNet_S Neural Network Model
def TripleNet_S(input_shape=(32, 32, 1), num_classes=10):

    # Shared convolutional layers
    input_img = layers.Input(shape=input_shape)
    conv1 = layers.Conv2D(32, (3, 3),
                          activation='relu',
                          padding='same')(input_img)
    conv1 = layers.MaxPooling2D((2, 2), padding='same')(conv1)
    conv2 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(conv1)
    conv2 = layers.MaxPooling2D((2, 2), padding='same')(conv2)
    conv3 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv2)
    conv3 = layers.MaxPooling2D((2, 2), padding='same')(conv3)
    conv4 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    conv4 = layers.MaxPooling2D((2, 2), padding='same')(conv4)

    # Layers
    anchor = layers.Flatten()(conv3)
    anchor = layers.Dense(256, activation='relu')(anchor)
    anchor = layers.Dropout(0.5)(anchor)
    anchor = layers.Dense(num_classes, activation='softmax', name='anchor')(anchor)

    positive = layers.Flatten()(conv3)
    positive = layers.Dense(256, activation='relu')(positive)
    positive = layers.Dropout(0.5)(positive)
    positive = layers.Dense(num_classes, activation='softmax', name='positive')(positive)

    negative = layers.Flatten()(conv3)
    negative = layers.Dense(256, activation='relu')(negative)
    negative = layers.Dropout(0.5)(negative)
    negative = layers.Dense(num_classes, activation='softmax', name='negative')(negative)

    # BiFPN branches
    branch1 = layers.Flatten()(conv4)
    branch1 = layers.Dense(256, activation='relu')(branch1)
    branch1 = layers.Dropout(0.5)(branch1)
    branch1 = layers.Dense(num_classes, activation='softmax', name='branch1')(branch1)

    # BiFPN branches
    branch2 = layers.Flatten()(conv4)
    branch2 = layers.Dense(256, activation='relu')(branch2)
    branch2 = layers.Dropout(0.5)(branch2)
    branch2 = layers.Dense(num_classes, activation='softmax', name='branch2')(branch2)

    # BiFPN branches
    branch3 = layers.Flatten()(conv4)
    branch3 = layers.Dense(256, activation='relu')(branch3)
    branch3 = layers.Dropout(0.5)(branch3)
    branch3 = layers.Dense(num_classes, activation='softmax', name='branch3')(branch3)

    # BiFPN branches
    branch4 = layers.Flatten()(conv4)
    branch4 = layers.Dense(256, activation='relu')(branch4)
    branch4 = layers.Dropout(0.5)(branch4)
    branch4 = layers.Dense(num_classes, activation='softmax', name='branch4')(branch4)

    # Fusion layer
    fusion = layers.Average()([anchor, positive, negative, branch1, branch2, branch3, branch4])

    model = models.Model(inputs=input_img, outputs=fusion)
    return model

# Train Test split
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# Build and compile the model
model = TripleNet_S()
bbox = (3, 3, 30, 30)

batch_size = 32;


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Display model summary
model.summary()

# Train the model
history = model.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test))

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc}")

# Plot training history
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend(loc='lower right')
plt.show()
# Out:
# Train images shape: (42000, 32, 32)
# Test images shape: (18000, 32, 32)
# Train labels shape: (42000,)
# Test labels shape: (18000,)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 32, 32, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 32, 32, 32)           320       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)           0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 16, 16, 64)           18496     ['max_pooling2d[0][0]']
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)             0         ['conv2d_1[0][0]']
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 128)            73856     ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)            0         ['conv2d_2[0][0]']
#  g2D)
#
#  conv2d_3 (Conv2D)           (None, 4, 4, 128)            147584    ['max_pooling2d_2[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 2, 2, 128)            0         ['conv2d_3[0][0]']
#  g2D)
#
#  flatten (Flatten)           (None, 2048)                 0         ['max_pooling2d_2[0][0]']
#
#  flatten_1 (Flatten)         (None, 2048)                 0         ['max_pooling2d_2[0][0]']
#
#  flatten_2 (Flatten)         (None, 2048)                 0         ['max_pooling2d_2[0][0]']
#
#  flatten_3 (Flatten)         (None, 512)                  0         ['max_pooling2d_3[0][0]']
#
#  flatten_4 (Flatten)         (None, 512)                  0         ['max_pooling2d_3[0][0]']
#
#  flatten_5 (Flatten)         (None, 512)                  0         ['max_pooling2d_3[0][0]']
#
#  flatten_6 (Flatten)         (None, 512)                  0         ['max_pooling2d_3[0][0]']
#
#  dense (Dense)               (None, 256)                  524544    ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 256)                  524544    ['flatten_1[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  524544    ['flatten_2[0][0]']
#
#  dense_3 (Dense)             (None, 256)                  131328    ['flatten_3[0][0]']
#
#  dense_4 (Dense)             (None, 256)                  131328    ['flatten_4[0][0]']
#
#  dense_5 (Dense)             (None, 256)                  131328    ['flatten_5[0][0]']
#
#  dense_6 (Dense)             (None, 256)                  131328    ['flatten_6[0][0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['dense[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense_1[0][0]']
#
#  dropout_2 (Dropout)         (None, 256)                  0         ['dense_2[0][0]']
#
#  dropout_3 (Dropout)         (None, 256)                  0         ['dense_3[0][0]']
#
#  dropout_4 (Dropout)         (None, 256)                  0         ['dense_4[0][0]']
#
#  dropout_5 (Dropout)         (None, 256)                  0         ['dense_5[0][0]']
#
#  dropout_6 (Dropout)         (None, 256)                  0         ['dense_6[0][0]']
#
#  anchor (Dense)              (None, 10)                   2570      ['dropout[0][0]']
#
#  positive (Dense)            (None, 10)                   2570      ['dropout_1[0][0]']
#
#  negative (Dense)            (None, 10)                   2570      ['dropout_2[0][0]']
#
#  branch1 (Dense)             (None, 10)                   2570      ['dropout_3[0][0]']
#
#  branch2 (Dense)             (None, 10)                   2570      ['dropout_4[0][0]']
#
#  branch3 (Dense)             (None, 10)                   2570      ['dropout_5[0][0]']
#
#  branch4 (Dense)             (None, 10)                   2570      ['dropout_6[0][0]']
#
#  average (Average)           (None, 10)                   0         ['anchor[0][0]',
#                                                                      'positive[0][0]',
#                                                                      'negative[0][0]',
#                                                                      'branch1[0][0]',
#                                                                      'branch2[0][0]',
#                                                                      'branch3[0][0]',
#                                                                      'branch4[0][0]']
#
# ==================================================================================================
# Total params: 2357190 (8.99 MB)
# Trainable params: 2357190 (8.99 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/50
# 329/329 [==============================] - 17s 17ms/step - loss: 1.4204 - accuracy: 0.5097 - val_loss: 0.6155 - val_accuracy: 0.8119
# Epoch 2/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.5505 - accuracy: 0.8423 - val_loss: 0.4312 - val_accuracy: 0.8712
# Epoch 3/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.4086 - accuracy: 0.8865 - val_loss: 0.3770 - val_accuracy: 0.8894
# Epoch 4/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.3390 - accuracy: 0.9071 - val_loss: 0.3332 - val_accuracy: 0.9041
# Epoch 5/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.2941 - accuracy: 0.9181 - val_loss: 0.3112 - val_accuracy: 0.9129
# Epoch 6/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.2575 - accuracy: 0.9314 - val_loss: 0.2944 - val_accuracy: 0.9163
# Epoch 7/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.2284 - accuracy: 0.9394 - val_loss: 0.2899 - val_accuracy: 0.9177
# Epoch 8/50
# 329/329 [==============================] - 6s 20ms/step - loss: 0.2003 - accuracy: 0.9484 - val_loss: 0.2839 - val_accuracy: 0.9232
# Epoch 9/50
# 329/329 [==============================] - 7s 22ms/step - loss: 0.1801 - accuracy: 0.9538 - val_loss: 0.2851 - val_accuracy: 0.9232
# Epoch 10/50
# 329/329 [==============================] - 5s 14ms/step - loss: 0.1647 - accuracy: 0.9589 - val_loss: 0.2821 - val_accuracy: 0.9241
# Epoch 11/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1455 - accuracy: 0.9656 - val_loss: 0.2882 - val_accuracy: 0.9261
# Epoch 12/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1322 - accuracy: 0.9686 - val_loss: 0.3132 - val_accuracy: 0.9252
# Epoch 13/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1247 - accuracy: 0.9715 - val_loss: 0.3111 - val_accuracy: 0.9236
# Epoch 14/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.1098 - accuracy: 0.9760 - val_loss: 0.3147 - val_accuracy: 0.9250
# Epoch 15/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.1012 - accuracy: 0.9800 - val_loss: 0.3195 - val_accuracy: 0.9262
# Epoch 16/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0931 - accuracy: 0.9819 - val_loss: 0.3330 - val_accuracy: 0.9271
# Epoch 17/50
# 329/329 [==============================] - 5s 15ms/step - loss: 0.0922 - accuracy: 0.9818 - val_loss: 0.3428 - val_accuracy: 0.9241
# Epoch 18/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0793 - accuracy: 0.9861 - val_loss: 0.3575 - val_accuracy: 0.9244
# Epoch 19/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0746 - accuracy: 0.9882 - val_loss: 0.3400 - val_accuracy: 0.9293
# Epoch 20/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0693 - accuracy: 0.9894 - val_loss: 0.3532 - val_accuracy: 0.9289
# Epoch 21/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0801 - accuracy: 0.9848 - val_loss: 0.3645 - val_accuracy: 0.9237
# Epoch 22/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0694 - accuracy: 0.9884 - val_loss: 0.3495 - val_accuracy: 0.9267
# Epoch 23/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0672 - accuracy: 0.9891 - val_loss: 0.3754 - val_accuracy: 0.9259
# Epoch 24/50
# 329/329 [==============================] - 5s 14ms/step - loss: 0.0825 - accuracy: 0.9830 - val_loss: 0.3848 - val_accuracy: 0.9246
# Epoch 25/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0666 - accuracy: 0.9884 - val_loss: 0.3859 - val_accuracy: 0.9284
# Epoch 26/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0586 - accuracy: 0.9913 - val_loss: 0.3830 - val_accuracy: 0.9276
# Epoch 27/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0563 - accuracy: 0.9918 - val_loss: 0.3783 - val_accuracy: 0.9296
# Epoch 28/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0587 - accuracy: 0.9912 - val_loss: 0.3947 - val_accuracy: 0.9281
# Epoch 29/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0556 - accuracy: 0.9912 - val_loss: 0.3998 - val_accuracy: 0.9228
# Epoch 30/50
# 329/329 [==============================] - 5s 14ms/step - loss: 0.0645 - accuracy: 0.9879 - val_loss: 0.4019 - val_accuracy: 0.9181
# Epoch 31/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0577 - accuracy: 0.9906 - val_loss: 0.4016 - val_accuracy: 0.9286
# Epoch 32/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0542 - accuracy: 0.9915 - val_loss: 0.3891 - val_accuracy: 0.9315
# Epoch 33/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0490 - accuracy: 0.9925 - val_loss: 0.3966 - val_accuracy: 0.9309
# Epoch 34/50
# 329/329 [==============================] - 4s 14ms/step - loss: 0.0717 - accuracy: 0.9851 - val_loss: 0.4072 - val_accuracy: 0.9247
# Epoch 35/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0649 - accuracy: 0.9874 - val_loss: 0.4194 - val_accuracy: 0.9253
# Epoch 36/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0523 - accuracy: 0.9924 - val_loss: 0.4203 - val_accuracy: 0.9293
# Epoch 37/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0428 - accuracy: 0.9939 - val_loss: 0.4076 - val_accuracy: 0.9330
# Epoch 38/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0433 - accuracy: 0.9940 - val_loss: 0.4225 - val_accuracy: 0.9309
# Epoch 39/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0428 - accuracy: 0.9937 - val_loss: 0.4329 - val_accuracy: 0.9324
# Epoch 40/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0412 - accuracy: 0.9940 - val_loss: 0.4448 - val_accuracy: 0.9284
# Epoch 41/50
# 329/329 [==============================] - 5s 14ms/step - loss: 0.0580 - accuracy: 0.9896 - val_loss: 0.4709 - val_accuracy: 0.9157
# Epoch 42/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0730 - accuracy: 0.9844 - val_loss: 0.4341 - val_accuracy: 0.9293
# Epoch 43/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0509 - accuracy: 0.9915 - val_loss: 0.4386 - val_accuracy: 0.9301
# Epoch 44/50
# 329/329 [==============================] - 4s 13ms/step - loss: 0.0418 - accuracy: 0.9938 - val_loss: 0.4302 - val_accuracy: 0.9303
# Epoch 45/50
# 329/329 [==============================] - 4s 12ms/step - loss: 0.0392 - accuracy: 0.9946 - val_loss: 0.4416 - val_accuracy: 0.9306
# Epoch 46/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0396 - accuracy: 0.9947 - val_loss: 0.4355 - val_accuracy: 0.9308
# Epoch 47/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0399 - accuracy: 0.9943 - val_loss: 0.4466 - val_accuracy: 0.9297
# Epoch 48/50
# 329/329 [==============================] - 5s 14ms/step - loss: 0.0385 - accuracy: 0.9945 - val_loss: 0.4473 - val_accuracy: 0.9311
# Epoch 49/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0537 - accuracy: 0.9901 - val_loss: 0.4684 - val_accuracy: 0.9247
# Epoch 50/50
# 329/329 [==============================] - 4s 11ms/step - loss: 0.0587 - accuracy: 0.9882 - val_loss: 0.4586 - val_accuracy: 0.9274
# 563/563 - 1s - loss: 0.4586 - accuracy: 0.9274 - 1s/epoch - 3ms/step
# Test accuracy: 0.9274444580078125

# %%
# Make predictions
import cv2
predictions = model.predict(x_test)


# Plot a few test images with their predicted labels
plt.figure(figsize=(15, 15))
for i in range(8):
    plt.subplot(8, 8, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    temp = cv2.rectangle(x_test[i].copy(), (bbox[0], bbox[1]), (bbox[2], bbox[3]), (0, 255, 0), 1)
    plt.imshow(temp, cmap=plt.cm.binary)
    plt.xlabel(f'Predicted: {tf.argmax(predictions[i]).numpy()}')
plt.show()
# Out:
# 563/563 [==============================] - 2s 3ms/step

# %%
import matplotlib.patches as patches
import numpy as np
image_size = 32

def bounding_box_intersection_over_union(box_predicted, box_truth):
    # get (x, y) coordinates of intersection of bounding boxes
    top_x_intersect = max(box_predicted[0], box_truth[0])
    top_y_intersect = max(box_predicted[1], box_truth[1])
    bottom_x_intersect = min(box_predicted[2], box_truth[2])
    bottom_y_intersect = min(box_predicted[3], box_truth[3])

    # calculate area of the intersection bb (bounding box)
    intersection_area = max(0, bottom_x_intersect - top_x_intersect + 1) * max(
        0, bottom_y_intersect - top_y_intersect + 1
    )

    # calculate area of the prediction bb and ground-truth bb
    box_predicted_area = (box_predicted[2] - box_predicted[0] + 1) * (
        box_predicted[3] - box_predicted[1] + 1
    )
    box_truth_area = (box_truth[2] - box_truth[0] + 1) * (
        box_truth[3] - box_truth[1] + 1
    )

    # calculate intersection over union by taking intersection
    # area and dividing it by the sum of predicted bb and ground truth
    # bb areas subtracted by  the interesection area

    # return ioU
    return intersection_area / float(
        box_predicted_area + box_truth_area - intersection_area
    )
L = 28
i, mean_iou = 0, 0

for input_image in x_test[:5]:
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 8))
    im = input_image

    # Display the image
    ax1.imshow(im)
    ax2.imshow(im)

    input_image = cv2.resize(
        input_image, (image_size, image_size), interpolation=cv2.INTER_AREA
    )
    input_image = np.expand_dims(input_image, axis=0)
    preds = model.predict(input_image)[0]

    (h, w) = (im).shape[0:2]

    top_left_x, top_left_y = int(preds[0] * w), int(preds[1] * h)

    bottom_right_x, bottom_right_y = int(preds[2] + L), int(preds[3] + L )

    box_predicted = [top_left_x, top_left_y, bottom_right_x, bottom_right_y]
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax1.add_patch(rect)
    ax1.set_xlabel(
        "Predicted: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
    )

    top_left_x, top_left_y = int(y_test[i][0] + 2), int(y_test[i][1] + 2)

    bottom_right_x, bottom_right_y = int(y_test[i][2] + L), int(y_test[i][3] + L)

    box_truth = top_left_x, top_left_y, bottom_right_x, bottom_right_y

    mean_iou += bounding_box_intersection_over_union(box_predicted, box_truth)
    # Create the bounding box
    rect = patches.Rectangle(
        (top_left_x, top_left_y),
        bottom_right_x - top_left_x,
        bottom_right_y - top_left_y,
        facecolor="none",
        edgecolor="red",
        linewidth=1,
    )
    # Add the bounding box to the image
    ax2.add_patch(rect)
    ax2.set_xlabel(
        "Target: "
        + str(top_left_x)
        + ", "
        + str(top_left_y)
        + ", "
        + str(bottom_right_x)
        + ", "
        + str(bottom_right_y)
        + "\n"
        + "IoU"
        + str(bounding_box_intersection_over_union(box_predicted, box_truth))
    )
    i = i + 1

plt.show()
# Out:
# 1/1 [==============================] - 0s 209ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 33ms/step
